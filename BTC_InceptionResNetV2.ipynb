# %%
#import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB2,EfficientNetB6,EfficientNetB7,InceptionV3,InceptionResNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix,classification_report
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#create labels
classes=[]
filename=r"/content/drive/MyDrive/Data/MRI Images/"
for sub_folder in os.listdir(os.path.join(filename,'Training')):
    classes.append(sub_folder)
print(classes)
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'pituitary_tumor', 'no_tumor']

# %%
#resize images and put together Training and Testing folder
X_train = []
y_train = []
image_size = 160
for i in classes:
    path_train = os.path.join(filename,'Training',i)
    for j in tqdm(os.listdir(path_train)): #Instantly make your loops show a smart progress meter 
        img = cv2.imread(os.path.join(path_train,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
    path_test = os.path.join(filename,'Testing',i)
    for j in tqdm(os.listdir(path_test)):
        img = cv2.imread(os.path.join(path_test,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 836/836 [00:15<00:00, 52.80it/s]
# 100%|██████████| 100/100 [00:03<00:00, 32.03it/s]
# 100%|██████████| 822/822 [00:17<00:00, 47.92it/s]
# 100%|██████████| 115/115 [00:02<00:00, 41.37it/s]
# 100%|██████████| 827/827 [00:14<00:00, 58.29it/s]
# 100%|██████████| 74/74 [00:50<00:00,  1.48it/s]
# 100%|██████████| 395/395 [00:06<00:00, 61.88it/s]
# 100%|██████████| 105/105 [00:02<00:00, 41.11it/s]

# %%
#data augmentation
X_train, y_train = shuffle(X_train,y_train, random_state=42)
datagen = ImageDataGenerator(
    rotation_range=7,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.1,
    horizontal_flip=True)

datagen.fit(X_train)
X_train.shape
lb = LabelEncoder()

# %%
#train and test splitting 
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.15,random_state=42,stratify=y_train)

labels_train=lb.fit(y_train)
y_train=lb.transform(y_train)
y_test=lb.transform(y_test)

print(y_train)
# Out:
# [3 3 2 ... 3 3 0]

# %%
#load EfficientNet
InceptionResNetV2=InceptionResNetV2(weights='imagenet', include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 6s 0us/step
# 219070464/219055592 [==============================] - 6s 0us/step

# %%
#train the model
tf.random.set_seed(79)
model = InceptionResNetV2.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=InceptionResNetV2.input, outputs = model)
opt = Adam(
    learning_rate=0.000023,
    epsilon=1e-08,
    clipnorm=1.0)

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# summarize the model
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 79, 79, 32)   864         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 79, 79, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 79, 79, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 77, 77, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 77, 77, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 77, 77, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 77, 77, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 77, 77, 64)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 77, 77, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 38, 38, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 38, 38, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 38, 38, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 38, 38, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 36, 36, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 36, 36, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 36, 36, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 17, 17, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 17, 17, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 17, 17, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 17, 17, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 17, 17, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 17, 17, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 17, 17, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 17, 17, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 17, 17, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 17, 17, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 17, 17, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 17, 17, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 17, 17, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 17, 17, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 17, 17, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 17, 17, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 17, 17, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 17, 17, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 17, 17, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 17, 17, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 17, 17, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 17, 17, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 17, 17, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 17, 17, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 17, 17, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 17, 17, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 17, 17, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 17, 17, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 17, 17, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 17, 17, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 17, 17, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 17, 17, 320)  0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 17, 17, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 17, 17, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 17, 17, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 17, 17, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 17, 17, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 17, 17, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 17, 17, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 17, 17, 320)  0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 17, 17, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 17, 17, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 17, 17, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 17, 17, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 17, 17, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 17, 17, 320)  0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 17, 17, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 17, 17, 320)  0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 17, 17, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 17, 17, 320)  0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 17, 17, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 17, 17, 320)  0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 17, 17, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 17, 17, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 17, 17, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 17, 17, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 17, 17, 320)  0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 32)  96          ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 17, 17, 32)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 32)   10240       ['block35_7_ac[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 48)   13824       ['activation_57[0][0]']
#
# ...
#  conv2d_189 (Conv2D)            (None, 3, 3, 224)    129024      ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 3, 3, 224)   672         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 3, 3, 224)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 3, 3, 256)    172032      ['activation_189[0][0]']
#
#  batch_normalization_187 (Batch  (None, 3, 3, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 3, 3, 256)   768         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 3, 3, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 3, 3, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 3, 3, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 3, 3, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 3, 3, 192)   576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 3, 3, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 3, 3, 224)   672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 3, 3, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 3, 3, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 3, 3, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 3, 3, 256)   768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 3, 3, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 3, 3, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 3, 3, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 3, 3, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 3, 3, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 3, 3, 224)    129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 3, 3, 224)   672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 3, 3, 224)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 3, 3, 256)    172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 3, 3, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 3, 3, 256)   768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 3, 3, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 3, 3, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 3, 3, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 3, 3, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 3, 3, 192)   576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 3, 3, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 3, 3, 224)   672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 3, 3, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 3, 3, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 3, 3, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 3, 3, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 3, 3, 256)   768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 3, 3, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 3, 3, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 3, 3, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 3, 3, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 3, 3, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 3, 3, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 3, 3, 1536)   0           ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  obalAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 1536)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_1 (Dense)                (None, 4)            6148        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 54,342,884
# Trainable params: 54,282,340
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# None

# %%
# fit the model
early_stopping_cb=keras.callbacks.EarlyStopping(patience=3,restore_best_weights=True)


history=model.fit(X_train ,y_train,validation_data = (X_test,y_test),epochs=70,
    batch_size=8,callbacks=[early_stopping_cb])
# Out:
# Epoch 1/70
# 348/348 [==============================] - 101s 163ms/step - loss: 0.7709 - accuracy: 0.6959 - val_loss: 0.2937 - val_accuracy: 0.8963
# Epoch 2/70
# 348/348 [==============================] - 49s 141ms/step - loss: 0.3352 - accuracy: 0.8814 - val_loss: 0.4966 - val_accuracy: 0.9146
# Epoch 3/70
# 348/348 [==============================] - 49s 141ms/step - loss: 0.1768 - accuracy: 0.9339 - val_loss: 0.8014 - val_accuracy: 0.9289
# Epoch 4/70
# 348/348 [==============================] - 50s 144ms/step - loss: 0.1063 - accuracy: 0.9669 - val_loss: 0.8212 - val_accuracy: 0.9390

# %%
#plot loss and accuracy
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)

# %%
loss, accuracy = model.evaluate(X_test,y_test)
# Out:
# 16/16 [==============================] - 3s 142ms/step - loss: 0.2937 - accuracy: 0.8963

# %%
#print accuracy    
print('Accuracy: %f' % (accuracy*100))
# Out:
# Accuracy: 89.634144

# %%
#acuracy and loss
print(f'accuracy : {round(accuracy*100,3)} \n loss : {round(loss,3)}')
# Out:
# accuracy : 89.634
#  loss : 0.294

# %%
y_test_labels=lb.inverse_transform(y_test)

#predicted values
pred=np.argmax(model.predict(X_test),axis=1)
pred_labels=lb.inverse_transform(pred)
#pred_labels

# %%
pd.Series(pred_labels).value_counts()
# Out:
# pituitary_tumor     145
# glioma_tumor        137
# meningioma_tumor    134
# no_tumor             76
# dtype: int64

# %%
cm = confusion_matrix(y_test,pred)
fig,ax= plt.subplots(figsize=(10.2,8.1))
a=sns.color_palette("winter_r")  #_r inverts the palette
sns.heatmap(cm, annot=True,fmt='g',linewidths=1,linecolor='white',robust=True,annot_kws={"size":18},cmap=a)
 #annot_kws: settings about annotations
ax.xaxis.set_ticklabels(classes); ax.yaxis.set_ticklabels(classes);
plt.yticks(va="center")
plt.title('Confusion Matrix',fontsize=18,pad=18)
plt.xlabel('Actual class',labelpad=22,fontsize=14)
plt.ylabel('Predicted class',labelpad=22,fontsize=14)
#plt.savefig(os.path.join('plots/','EfficientNetB3_confusion_matrix.png'), dpi=300)
# Out:
# Text(70.8, 0.5, 'Predicted class')

# %%
#y_test_labels
print(classification_report(y_test,pred,target_names=classes))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.91      0.89      0.90       141
# meningioma_tumor       0.88      0.84      0.86       141
#  pituitary_tumor       0.87      0.88      0.87        75
#         no_tumor       0.91      0.98      0.94       135
#
#         accuracy                           0.90       492
#        macro avg       0.89      0.90      0.89       492
#     weighted avg       0.90      0.90      0.90       492
